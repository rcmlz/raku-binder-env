# %% [markdown]
# -----
#
# # OpenAI
#
# ["Jupyter::Chatbook" Raku package](https://raku.land/zef:antononcube/Jupyter::Chatbook)
#
# ---
#
# Get your API-KEY from https://platform.openai.com/api-keys

# %%
%*ENV<OPENAI_API_KEY>='put-your-key-here'

# %%
use WWW::OpenAI;

# %%
openai-completion('How many people live in EU?', max-tokens=> 120, format =>'values')

# %%
#% openai
Randomly generate 3 dog names and 4 cat names.

# %% [markdown]
# see https://github.com/antononcube/Raku-Jupyter-Chatbook/tree/master/eg for more examples.
